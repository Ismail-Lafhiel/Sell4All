# %% [markdown]
# ### Import pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lire de fichier

# %%
df = pd.read_csv("data-sell4all.csv")

# %% [markdown]
# ### Afficher data

# %%
df.head()
# Out:
#       Pays Age   Genre Dépenses des clients
# 0   France  32  Female                150.5
# 1  Germany  45    Male               200.75
# 2    Spain  28  Female                75.25
# 3    Italy  39    Male                  180
# 4       UK  52  Female                250.3

# %% [markdown]
# ###  Afficher un résumé technique des données disponibles dans le fichier CSV

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Pays                  65 non-null     object
#  1   Age                   63 non-null     object
#  2   Genre                 64 non-null     object
#  3   Dépenses des clients  64 non-null     object
# dtypes: object(4)
# memory usage: 2.2+ KB

# %% [markdown]
# #### nombre de lignes et columns dans fichier CSV

# %%
nbr_lignes, num_cols = df.shape

# %% [markdown]
# ##### nombre des lignes

# %%
nbr_lignes
# Out:
# 65

# %% [markdown]
# ##### nombre des columns

# %%
num_cols
# Out:
# 4

# %% [markdown]
# #### les types de données des champs du fichier CSV

# %%
df.dtypes
# Out:
# Pays                    object
# Age                     object
# Genre                   object
# Dépenses des clients    object
# dtype: object

# %% [markdown]
# ### Calculer la médiane et la moyenne des colonnes "Âge" et "Dépenses des clients"

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['Dépenses des clients'] = pd.to_numeric(df['Dépenses des clients'], errors='coerce')

# %%
age_median = df['Age'].median()
age_mean = df['Age'].mean()
expenses_median = df['Dépenses des clients'].median()
expenses_mean = df['Dépenses des clients'].mean()

# %%
age_median
# Out:
# np.float64(36.0)

# %%
age_mean
# Out:
# np.float64(52.42372881355932)

# %%
expenses_median
# Out:
# np.float64(167.5)

# %%
expenses_mean
# Out:
# np.float64(34811.72948275862)

# %% [markdown]
# ### Créer une visualisation des données du graphique à barres des dépenses des clients par pays

# %%
df.isnull().sum()
# Out:
# Pays                    0
# Age                     6
# Genre                   1
# Dépenses des clients    7
# dtype: int64

# %%
df = df.dropna(subset=['Dépenses des clients', 'Pays'])

# %%
df.groupby('Pays')['Dépenses des clients'].sum()
# Out:
# Pays
# Atlantis             500.00
# Australia            210.50
# Brazil               195.25
# Digital Realm    1010101.01
# France              1543.00
# Germany             1608.75
# Italy               1443.25
# Japan                145.75
# Mars              999999.99
# Moon                   0.01
# Spain               1334.50
# UK                  1818.30
# USA                  180.00
# Name: Dépenses des clients, dtype: float64

# %%
country_expenses = df.groupby('Pays')['Dépenses des clients'].sum()
country_expenses = country_expenses.sort_index()

# %%
plt.figure(figsize=(12, 6))
country_expenses.plot(kind='bar', color='skyblue')
plt.title('Dépenses des clients par pays')
plt.xlabel('Pays')
plt.ylabel('Dépenses des clients (€)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Nettoyer les lignes avec moins de 10 € de dépenses client

# %%
cleaned_data = df[df['Dépenses des clients'] >= 10]

# %%
cleaned_data
# Out:
#              Pays     Age      Genre  Dépenses des clients
# 0          France    32.0     Female                150.50
# 1         Germany    45.0       Male                200.75
# 2           Spain    28.0     Female                 75.25
# 3           Italy    39.0       Male                180.00
# 4              UK    52.0     Female                250.30
# 5          France    22.0       Male                 90.00
# 6         Germany    36.0     Female                175.50
# 7           Spain    41.0       Male                120.75
# 8           Italy    29.0     Female                 95.25
# 9              UK    48.0       Male                220.00
# 10         France    35.0     Female                160.25
# 11        Germany    27.0       Male                 85.50
# 12          Spain    50.0     Female                190.75
# 13          Italy    33.0       Male                140.00
# 14             UK    44.0     Female                210.50
# ...

# %% [markdown]
# ### Nettoyer les doublons

# %%
cleaned_data = cleaned_data.drop_duplicates()

# %%
cleaned_data
# Out:
#              Pays     Age      Genre  Dépenses des clients
# 0          France    32.0     Female                150.50
# 1         Germany    45.0       Male                200.75
# 2           Spain    28.0     Female                 75.25
# 3           Italy    39.0       Male                180.00
# 4              UK    52.0     Female                250.30
# 5          France    22.0       Male                 90.00
# 6         Germany    36.0     Female                175.50
# 7           Spain    41.0       Male                120.75
# 8           Italy    29.0     Female                 95.25
# 9              UK    48.0       Male                220.00
# 10         France    35.0     Female                160.25
# 11        Germany    27.0       Male                 85.50
# 12          Spain    50.0     Female                190.75
# 13          Italy    33.0       Male                140.00
# 14             UK    44.0     Female                210.50
# ...

# %% [markdown]
# ### Écrire les données nettoyées dans un nouveau fichier CSV

# %%
cleaned_data = cleaned_data[['Pays', 'Age', 'Genre', 'Dépenses des clients']]
cleaned_data.to_csv('./data-sell4all-cleaned.csv', index=False)
